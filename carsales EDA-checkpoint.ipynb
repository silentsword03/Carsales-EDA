# %%
carsales_Profile = pandas_profiling.ProfileReport(carsales_df)
carsales_Profile.to_file("CarSales_Before_Processing.html")

# %%
pip install -q pandas-profiling
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
# cookiecutter 1.7.2 requires MarkupSafe<2.0.0, but you have markupsafe 2.0.1 which is incompatible.

# %%
import pandas as pd #importing required libraries
import numpy as np
# %matplotlib inline

# %%
df= pd.read_csv("Carsales.csv")#reading the dataset

# %%
df=df.drop(['Unnamed: 0'],axis=1)#drop columns not required

# %%
df.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover     68.0  2.50     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan    173.0  1.80     Gas          yes
# 2  Mercedes-Benz  35000.0      other    135.0  5.50  Petrol          yes
# 3  Mercedes-Benz  17800.0        van    162.0  1.80  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon     91.0  2.57   Other          yes
#
#    year    model  drive         class
# 0  2010     Kuga   full        Luxury
# 1  2011  E-Class   rear        Luxury
# 2  2008   CL 550   rear  Super Luxury
# 3  2012    B 180  front        Luxury
# 4  2013  E-Class   rear  Super Luxury

# %%
df.shape
# Out:
# (9463, 11)

# %%
df.describe()
# Out:
#                price      mileage         engV         year
# count    9463.000000  9463.000000  9463.000000  9463.000000
# mean    15948.897726   143.428036     2.637925  2006.525837
# std     23754.171644    95.855789     6.002845     7.062584
# min       259.350000     0.500000     0.100000  1953.000000
# 25%      5450.000000    77.000000     1.600000  2004.000000
# 50%      9500.000000   130.000000     2.000000  2008.000000
# 75%     16999.000000   195.000000     2.500000  2012.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %%
df.dtypes
# Out:
# car              object
# price           float64
# body             object
# mileage         float64
# engV            float64
# engType          object
# registration     object
# year              int64
# model            object
# drive            object
# class            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9463 entries, 0 to 9462
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9463 non-null   object
#  1   price         9463 non-null   float64
#  2   body          9463 non-null   object
#  3   mileage       9463 non-null   float64
#  4   engV          9463 non-null   float64
#  5   engType       9463 non-null   object
#  6   registration  9463 non-null   object
#  7   year          9463 non-null   int64
#  8   model         9463 non-null   object
#  9   drive         9463 non-null   object
#  10  class         9463 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 813.4+ KB

# %%
import pandas_profiling
carsales_Profile = pandas_profiling.ProfileReport(df)
carsales_Profile.to_file("CarSales_Before_Processing.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
for col in df.columns:
    print(col)
# Out:
# car
# price
# body
# mileage
# engV
# engType
# registration
# year
# model
# drive
# class

# %%
df1=df.groupby(['car'])['price'].mean().sort_values(ascending=False)[:10]

# %%
df1=df1.reset_index()

# %%
df1=df1.rename({'price':'Average_price'},axis=1)

# %%
df1
# Out:
#             car  Average_price
# 0       Bentley  226159.538462
# 1       Ferrari  167500.000000
# 2   Lamborghini  130000.000000
# 3      Maserati  110000.000000
# 4  Aston Martin  105000.000000
# 5         Tesla   99509.090909
# 6   Rolls-Royce   97500.000000
# 7      Cadillac   70833.333333
# 8    Land Rover   52976.187500
# 9       Porsche   48028.453488

# %%
df1.plot(kind='bar',figsize=(15,10),x='car',y='Average_price',title='Cars average price')
# Out:
# <AxesSubplot:title={'center':'Cars average price'}, xlabel='car'>

# %%
df.columns
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive', 'class'],
#       dtype='object')

# %%
df2=df.groupby(['car'])['mileage'].mean().sort_values(ascending=False)[:5]

# %%
df2=df2.reset_index()

# %%
df2
# Out:
#        car    mileage
# 0       ZX  249.00000
# 1  Mercury  237.00000
# 2   Bogdan  220.00000
# 3     Saab  210.00000
# 4     Opel  195.85213

# %%
df2.plot(kind='bar',figsize=(15,10),x='car',y='mileage',title='Average mileage of cars')
# Out:
# <AxesSubplot:title={'center':'Average mileage of cars'}, xlabel='car'>

# %%
df
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover     68.0  2.50     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan    173.0  1.80     Gas          yes
# 2     Mercedes-Benz  35000.0      other    135.0  5.50  Petrol          yes
# 3     Mercedes-Benz  17800.0        van    162.0  1.80  Diesel          yes
# 4     Mercedes-Benz  33000.0      vagon     91.0  2.57   Other          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9458        Hyundai  14500.0  crossover    140.0  2.00     Gas          yes
# 9459     Volkswagen   2200.0      vagon    150.0  1.60  Petrol          yes
# 9460  Mercedes-Benz  18500.0  crossover    180.0  3.50  Petrol          yes
# 9461          Lexus  16999.0      sedan    150.0  3.50     Gas          yes
# 9462           Audi  22500.0      other     71.0  3.60  Petrol          yes
#
#       year      model  drive         class
# ...

# %%
df3=df.groupby(['car'])['price'].count().sort_values(ascending=False)[:10]

# %%
df3=df3.reset_index()

# %%
df3
# Out:
#              car  price
# 0     Volkswagen    927
# 1  Mercedes-Benz    885
# 2            BMW    684
# 3         Toyota    529
# 4            VAZ    488
# 5        Renault    467
# 6           Audi    456
# 7           Opel    399
# 8          Skoda    368
# 9         Nissan    364

# %%
df3=df3.rename({'price':'value_count'},axis=1)

# %%
df3
# Out:
#              car  value_count
# 0     Volkswagen          927
# 1  Mercedes-Benz          885
# 2            BMW          684
# 3         Toyota          529
# 4            VAZ          488
# 5        Renault          467
# 6           Audi          456
# 7           Opel          399
# 8          Skoda          368
# 9         Nissan          364

# %%
df3.plot(kind='bar',x='car')
# Out:
# <AxesSubplot:xlabel='car'>

# %%
df.columns
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive', 'class'],
#       dtype='object')

# %%
df4=df.groupby(['year','car'])['price'].count().sort_values(ascending=False)

# %%
df4=df4.reset_index()

# %%
df4=df4.rename({'price':'sales'},axis=1)

# %%
df4
# Out:
#       year            car  sales
# 0     2012     Volkswagen    104
# 1     2011     Volkswagen     97
# 2     2012        Renault     94
# 3     2008         Toyota     90
# 4     2008     Mitsubishi     83
# ...    ...            ...    ...
# 1011  2009           Jeep      1
# 1012  1996     Land Rover      1
# 1013  1996          Lexus      1
# 1014  1996        Peugeot      1
# 1015  1953  Moskvich-AZLK      1
#
# [1016 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#sns.lineplot(data=df4,x='year',y='sales',hue='car')
fig, ax = plt.subplots(figsize=(20,8))
sns.lineplot(data=df4, x='year', y='sales', hue='car')
# Out:
# <AxesSubplot:xlabel='year', ylabel='sales'>
